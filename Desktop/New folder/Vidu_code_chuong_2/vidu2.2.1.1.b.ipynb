# %%
data = {
    "lop": "K18A",
    "mon_hoc": "Python nâng cao",
    "sinh_vien": [
        {
            "ho_ten": "Nguyen Van A",
            "nam_sinh": 2004,
            "diem_tb": 8.2
        },
        {
            "ho_ten": "Tran Van B",
            "nam_sinh": 2003,
            "diem_tb": 7.6
        }
    ],
    "giang_vien": {
        "ten": "CT",
        "email": "ct@uneti.edu"
    },
    "dang_mo": True,   # boolean trong Python khác với JSON (True/False viết hoa chữ cái đầu)
    "ghi_chu": None    # None trong Python tương đương null trong JSON
}
